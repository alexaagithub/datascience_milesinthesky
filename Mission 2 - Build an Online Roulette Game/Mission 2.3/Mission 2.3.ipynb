# %% [markdown]
# - the roulette has 18 red numbers, 18 black numbers and 1 green number (the zero)->introduce this number
# - the player won’t bet on “green” but rather see how it influences the final balance, so the bet choice should be either “black” or “red”
# - take into account that red/black and the green number don’t have the same probability of being drawn: $p_{red} = p_{black} = \frac{18}{18+18+1}=\frac{18}{37}$ and $p_{black} = \frac{1}{18+18+1}=\frac{1}{37}$
# - determine how much money the player ends up with.

# %%
import random
initial_balance = 1000 # the player starts with a balance of €1000
balance = initial_balance
bet_amount = 10 # amount to bet (it has to be lower than the initial_balance) it's the same for all the games
bet_choice = "red" # choose "red" or "black". the player bets only one of this colors for all the games
n = 50 #number of times a player can play the roulette. 
#since he's able to play continuously I didn't make having a positive balance a requirement 
list_outcome = [] #list to store the outcomes. before the 1st game it's empty

right = 0 #nº of times the player gets the color right

m = 5 #test

for i in range(n): #replace n with m to test
  print("Game nº. " + str(i+1))
  #probabilities for each color
  p_redblack = 18/37 #the probability for red and black is the same
  p_green = 1/37
  #use of choice() method from random library (imported above) to select a random value from a list with 'red', 'black', and 'green'

  #to each color in the list "colors" there is a correspondent probability in the list "probabilities"
  colors = ['red', 'black', 'green']
  probabilities = [p_redblack, p_redblack, p_green] 

  output = random.choices(colors, probabilities) #the output is a list with the color generated
  outcome = output[0]
  list_outcome.append(outcome)

  #there are only 2 possibilities, thus we only need if and else (no elifs)

  if outcome == bet_choice: #the player made the right guess in color
    change = bet_amount #change in balance. the player won, so he wins the double amount of the bet. the change is positive.
    balance += change #the balace at the end of the game
    right += 1
    print("Congrats! You won " + str(change) + "€. Your current balance is " + str(balance) + "€.")

  else: #the player got the color wrong
    change = -bet_amount #the player lost, so he loses the amount of the bet. the change is negative.
    balance += change
    print("Better luck next time. You lost " + str(abs(change)) + "€. Your current balance is " + str(balance) + "€.")


#I could also have used a while loop:
#i = 0
#while n>=i:
  #...
  # i+= 1

print("\n") #space between prints
print("List of colors: ", list_outcome)

dif = balance - initial_balance

print("\n")

print("The game is over. Your got the right color " + str(right) + " times.")

print("\n")

if dif>0: #the player won money
  print("Your balance is " + str(balance) + "€. You won " + str(dif) + "€. Congrats!")
elif dif<0: #the player lost money
  print("Your balance is " + str(balance) + "€. You lost " + str(abs(dif)) + "€. Better luck next time!")
else: #the player didn't win or lose money
  print("Your balance is " + str(balance) + "€.")
# Out:
# Game nº. 1
# Congrats! You won 10€. Your current balance is 1010€.
# Game nº. 2
# Better luck next time. You lost 10€. Your current balance is 1000€.
# Game nº. 3
# Congrats! You won 10€. Your current balance is 1010€.
# Game nº. 4
# Better luck next time. You lost 10€. Your current balance is 1000€.
# Game nº. 5
# Better luck next time. You lost 10€. Your current balance is 990€.
# Game nº. 6
# Better luck next time. You lost 10€. Your current balance is 980€.
# Game nº. 7
# Congrats! You won 10€. Your current balance is 990€.
# Game nº. 8
# Congrats! You won 10€. Your current balance is 1000€.
# Game nº. 9
# Better luck next time. You lost 10€. Your current balance is 990€.
# Game nº. 10
# Better luck next time. You lost 10€. Your current balance is 980€.
# Game nº. 11
# Better luck next time. You lost 10€. Your current balance is 970€.
# Game nº. 12
# Better luck next time. You lost 10€. Your current balance is 960€.
# Game nº. 13
# Better luck next time. You lost 10€. Your current balance is 950€.
# Game nº. 14
# Better luck next time. You lost 10€. Your current balance is 940€.
# Game nº. 15
# Congrats! You won 10€. Your current balance is 950€.
# Game nº. 16
# Congrats! You won 10€. Your current balance is 960€.
# Game nº. 17
# Better luck next time. You lost 10€. Your current balance is 950€.
# Game nº. 18
# Better luck next time. You lost 10€. Your current balance is 940€.
# Game nº. 19
# Better luck next time. You lost 10€. Your current balance is 930€.
# Game nº. 20
# Congrats! You won 10€. Your current balance is 940€.
# Game nº. 21
# Congrats! You won 10€. Your current balance is 950€.
# Game nº. 22
# Congrats! You won 10€. Your current balance is 960€.
# Game nº. 23
# Congrats! You won 10€. Your current balance is 970€.
# Game nº. 24
# Better luck next time. You lost 10€. Your current balance is 960€.
# Game nº. 25
# Congrats! You won 10€. Your current balance is 970€.
# Game nº. 26
# Better luck next time. You lost 10€. Your current balance is 960€.
# Game nº. 27
# Congrats! You won 10€. Your current balance is 970€.
# Game nº. 28
# Better luck next time. You lost 10€. Your current balance is 960€.
# Game nº. 29
# Congrats! You won 10€. Your current balance is 970€.
# Game nº. 30
# Better luck next time. You lost 10€. Your current balance is 960€.
# Game nº. 31
# Better luck next time. You lost 10€. Your current balance is 950€.
# Game nº. 32
# Congrats! You won 10€. Your current balance is 960€.
# Game nº. 33
# Better luck next time. You lost 10€. Your current balance is 950€.
# Game nº. 34
# Better luck next time. You lost 10€. Your current balance is 940€.
# Game nº. 35
# Better luck next time. You lost 10€. Your current balance is 930€.
# Game nº. 36
# Congrats! You won 10€. Your current balance is 940€.
# Game nº. 37
# Better luck next time. You lost 10€. Your current balance is 930€.
# Game nº. 38
# Better luck next time. You lost 10€. Your current balance is 920€.
# Game nº. 39
# Congrats! You won 10€. Your current balance is 930€.
# Game nº. 40
# Better luck next time. You lost 10€. Your current balance is 920€.
# Game nº. 41
# Better luck next time. You lost 10€. Your current balance is 910€.
# Game nº. 42
# Better luck next time. You lost 10€. Your current balance is 900€.
# Game nº. 43
# Better luck next time. You lost 10€. Your current balance is 890€.
# Game nº. 44
# Congrats! You won 10€. Your current balance is 900€.
# Game nº. 45
# Better luck next time. You lost 10€. Your current balance is 890€.
# Game nº. 46
# Congrats! You won 10€. Your current balance is 900€.
# Game nº. 47
# Better luck next time. You lost 10€. Your current balance is 890€.
# Game nº. 48
# Congrats! You won 10€. Your current balance is 900€.
# Game nº. 49
# Better luck next time. You lost 10€. Your current balance is 890€.
# Game nº. 50
# Congrats! You won 10€. Your current balance is 900€.
#
#
# List of colors:  ['red', 'black', 'red', 'black', 'black', 'black', 'red', 'red', 'black', 'black', 'black', 'black', 'black', 'black', 'red', 'red', 'black', 'black', 'black', 'red', 'red', 'red', 'red', 'black', 'red', 'black', 'red', 'black', 'red', 'black', 'black', 'red', 'green', 'black', 'black', 'red', 'black', 'black', 'red', 'black', 'black', 'black', 'black', 'red', 'black', 'red', 'black', 'red', 'black', 'red']
#
#
# The game is over. Your got the right color 20 times.
#
#
# Your balance is 900€. You lost 100€. Better luck next time!
