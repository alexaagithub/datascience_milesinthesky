# %% [markdown]
# **1. What is the total number of people with access to internet in the low income countries’ group?**

# %% [markdown]
# 1. Create a list with the values of population with access to internet ordered (in alphabetical order of countries)

# %%
internet_country = [4437830, 3323621, 618320, 207679, 1067680, 7702280, 41781, 21383226, 478499, 2862948, 76751, 1669033, 1301477, 2639933, 2571855, 6501130, 2469076, 2823581, 1052962, 317864, 895498, 13549424, 6002725, 1026563, 10840617, 7963533]

# %% [markdown]
# 2. Using the sum function, sum all the values from that list

# %%
sum (internet_country)
# Out:
# 103825886

# %% [markdown]
# **2. What is the average percentage of the population with access to internet among the low income countries?**

# %% [markdown]
# 1. Create a list with values of % population with access to internet ordered

# %%
perc_internet_country = [1.4, 15.9, 5.2, 4.3, 6.5, 8.6, 1.3, 18.6, 19.8, 21.8, 3.9, 33.0, 4.7, 13.8, 12.7, 20.8, 10.2, 21.8, 13.2, 2.0, 8.0, 30.9, 34.3, 12.4, 23.7, 26.7]

# %% [markdown]
# 2. Using the built-in function sum(), sum all the values from that list and assign it to a variable

# %%
sum_perc_int = sum (perc_internet_country)

# %% [markdown]
# 3. Check the length of the list with the built-in function len() and assign it to a variable

# %%
lenght_perc_int = len(perc_internet_country)

# %% [markdown]
# 4. Print the division of both

# %%
result_division = sum_perc_int/lenght_perc_int
print ("The average percentage of the population with access to internet among the low income countries is " + str(result_division) + "%.")
# Out:
# The average percentage of the population with access to internet among the low income countries is 14.44230769230769%.

# %% [markdown]
# **3. Which country from the low-income group has the highest percentage of the population with access to internet?**

# %% [markdown]
# 1. Get the max from the list of percentages and assign it to a variable

# %%
#highest percentage of population with internet access among low income countries
high_int = max(perc_internet_country)
#print(high_int)

# %% [markdown]
# 2. Using the list method index(), find the index of that value

# %%
h_index = perc_internet_country.index (max(perc_internet_country))
print (h_index)
# Out:
# 22

# %% [markdown]
# 3. Analyze the income_countries and check for duplicates (yes, there will be duplicates!)

# %%
l_inc_countries = ['Afghanistan', 'Burkina Faso', 'Burundi', 'Central African Republic', 'Chad', 'Democratic Republic of Congo', 'Eritrea', 'Eritrea', 'Ethiopia', 'Gambia', 'Guinea', 'Guinea-Bissau', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mozambique', 'Niger', 'Niger', 'Rwanda', 'Sierra Leone', 'Somalia', 'South Sudan', 'Sudan', 'Syria', 'Togo', 'Uganda', 'Yemen']

l = len (l_inc_countries)
print("lenght of the countries' list:" + str(l))
print("lenght of countries' percentages:" + str(lenght_perc_int))

#If lenght_perc_int<l there are duplicates
# Out:
# lenght of the countries' list:28
# lenght of countries' percentages:26

# %% [markdown]
# 4. Remove the duplicates (a small tip: a set has no duplicate values; creating a set from a list with duplicates will remove the duplicates)

# %%
set_lcountries = set(l_inc_countries)
#changing the variable l_inc_countries 
l_inc_countries = list(set_lcountries)

#to check if there are duplicates:
l = len(l_inc_countries)
print(l) #see if its equal to 26
# Out:
# 26

# %% [markdown]
# 5. Transform the set into a list again and order it (alphabetically)

# %%
#the transformation into a list is done
#I'll use the sorted() function to order the list alphabetically

l_inc_countries = sorted (l_inc_countries)
print(l_inc_countries)
# Out:
# ['Afghanistan', 'Burkina Faso', 'Burundi', 'Central African Republic', 'Chad', 'Democratic Republic of Congo', 'Eritrea', 'Ethiopia', 'Gambia', 'Guinea', 'Guinea-Bissau', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mozambique', 'Niger', 'Rwanda', 'Sierra Leone', 'Somalia', 'South Sudan', 'Sudan', 'Syria', 'Togo', 'Uganda', 'Yemen']

# %% [markdown]
# 6. Now, using the index obtained in the 2nd step, access to that list and get the name of the country

# %%
h_country = l_inc_countries[h_index]
print("The country with the highest percentage of internet access is " + h_country + "." )
# Out:
# The country with the highest percentage of internet access is Syria.

# %% [markdown]
# **4. If we add the lower-middle income countries, what is the average percentage of the population with access to internet (among the low- and lower-middle income countries)?**

# %% [markdown]
# 1. Create a variable with a list of the lower-middle income countries percentages

# %%
lm_perc_internet_country = [49.0, 21.4, 18.0, 47.1, 14.1, 41.8, 44.3, 40.5, 23.2, 57.2, 8.5, 8.6, 43.8, 55.7, 57.3, 33.8, 30.3, 37.9, 32.5, 32.1, 32.0, 47.7, 70.0, 22.6, 14.6, 38.2, 25.5, 32.5, 20.8, 35.3, 51.1, 74.4, 25.1, 21.4, 27.9, 36.0, 17.1, 70.6, 11.2, 60.1, 33.6, 29.9, 29.6, 11.9, 34.1, 22.0, 20.0, 27.5, 66.7, 62.6, 55.2, 25.7, 69.8, 27.9, 27.1]

# %% [markdown]
# 2. Concatenate it with the low income countries list and assign it to a variable

# %%
#list of low and lower-middle income countries' population percentage with access to the internet
t_internet_country = perc_internet_country + lm_perc_internet_country

# %% [markdown]
# 3. Get the sum and the length of the list

# %%
st = sum(t_internet_country)
lt = len(t_internet_country)

# %% [markdown]
# 4. Create a variable with the division between the two variables created before and print it

# %%
dt = st/lt
print ("The average percentage of the population with access to internet among low and lower-middle income countries is " + str(dt) + "%.")
# Out:
# The average percentage of the population with access to internet among low and lower-middle income countries is 29.016049382716034%.

# %% [markdown]
# **5. What is the percentage of the population in Europe & Central Asia with some access to Internet in 2019?**

# %% [markdown]
# 1. Create the dictionary and assign it to a variable

# %%
region_internet = {'East Asia & Pacific': {
     'population': 2328453894, 'pop_internet': 1332951361
     },
 'Europe & Central Asia': {
     'population': 921455672, 'pop_internet': 737270551
     },
 'Latin America & Caribbean': {
     'population': 652196854,'pop_internet': 430064244
     },
 'Middle East & North Africa': {
     'population': 464554123,'pop_internet': 301099965
     },
 'North America': {
     'population': 367553264, 'pop_internet': 326887183
     },
 'South Asia': {
     'population': 1856882402, 'pop_internet': 527829719
     },
 'Sub-Saharan Africa': {
     'population': 1135714317, 'pop_internet': 276618220
     }
}

# %% [markdown]
# 2. Access to the element of Europe & Central Asia of the dictionary and assign it to a variable

# %%
list_eurasia = region_internet['Europe & Central Asia']
print(list_eurasia)
# Out:
# {'population': 921455672, 'pop_internet': 737270551}

# %% [markdown]
# 3. Create a variable for the Europe & Central Asia population

# %%
pop_eurasia = list_eurasia['population']
#print(pop_eurasia)
pop_eurasia_internet = list_eurasia['pop_internet']
print(pop_eurasia_internet)
# Out:
# 737270551

# %% [markdown]
# 4. Create a variable with the division between the two variables created before
# 5. Print it

# %%
result_eurasia = (pop_eurasia_internet/pop_eurasia)*100
print("The percentage of the population in Europe & Central Asia with some access to Internet in 2019 was " + str(result_eurasia) + "%.")
# Out:
# The percentage of the population in Europe & Central Asia with some access to Internet in 2019 was 80.0115049918538%.

# %% [markdown]
# **6. What is the percentage of the population in the world with some access to Internet in 2019?**

# %% [markdown]
# 1. Using the values() method, get a list with all the values of the population with access to internet in 2019.

# %%
val_dic = region_internet.values()
list_pop_int = []
for i in val_dic:
  list_pop_int.append(i['pop_internet'])
print(list_pop_int)
# Out:
# [1332951361, 737270551, 430064244, 301099965, 326887183, 527829719, 276618220]

# %% [markdown]
# alternative: using just a loop

# %%
list_pop_int2 = []
for i in region_internet:
     list_pop_int2.append(region_internet[i]['pop_internet'])
print(list_pop_int2)
# Out:
# [1332951361, 737270551, 430064244, 301099965, 326887183, 527829719, 276618220]

# %% [markdown]
# 2. Using the built-in function sum(), get the sum of all the list elements and assign it into a variable

# %%
sum_list_pop = sum(list_pop_int)
print(sum_list_pop)
# Out:
# 3932721243

# %% [markdown]
# 3. Create a variable with the World population

# %%
#I followed steps 1 and 2 but for the all world population
#the val_dic variable was already defined

list_all_pop = []
for i in val_dic:
  #print(i)
  list_all_pop.append(i['population'])
  #print(i['population'])

sum_all_pop = sum(list_all_pop)
print(sum_all_pop)
# Out:
# 7726810526

# %% [markdown]
# 4. Create a variable with the division between the two variables created before

# %%
value_allpop = (sum_list_pop/sum_all_pop)
percvalue_allpop = value_allpop*100

# %% [markdown]
# 5. Print it

# %%
print("The percentage of the world population with some access to Internet in 2019 is " + str(percvalue_allpop)+ "%.")
# Out:
# The percentage of the world population with some access to Internet in 2019 is 50.897083987846706%.

# %% [markdown]
# **7. What is the percentage of population in the group North America, Latin America & Caribbean with some access to Internet in 2019?**

# %% [markdown]
# 1. Get the values for population and pop_internet of ‘North America’ and ‘Latin America & Caribbean’ by accessing to the nested dict and assign them to variables

# %%
list_northamerica = region_internet['North America']
list_lamerica_cari = region_internet['Latin America & Caribbean']

#print("North America: ", list_northamerica)
#print("Latin America & Caribbean: ", list_lamerica_cari)

population_northamerica = list_northamerica['population']
population_int_northamerica = list_northamerica['pop_internet']
population_lamerica_cari = list_lamerica_cari['population']
population_int_lamerica_cari = list_lamerica_cari['pop_internet']

#print (population_northamerica, population_int_northamerica, population_lamerica_cari, population_int_lamerica_cari)

# %% [markdown]
# 2. Sum the values of pop_internet and divide it by the sum of the values of population. Assign the result of the division to a variable

# %%
allpopint = population_int_lamerica_cari + population_int_northamerica
allpop = population_northamerica + population_lamerica_cari
result_america = allpopint/allpop 
result_america_perc = result_america * 100

# %% [markdown]
# 3. Print it.

# %%
print("The percentage of population in North and Latin America and Caribbean with some access to Internet in 2019 was " + str(result_america_perc) + "%.")
# Out:
# The percentage of population in North and Latin America and Caribbean with some access to Internet in 2019 was 74.229109037475%.
