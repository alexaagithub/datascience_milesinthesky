# %% [markdown]
# **1. Of all energy used in the world, how much comes from natural gas, coal and oil?**

# %% [markdown]
# 1. Create a variable for each source: gas, coal and oil

# %%
#gas 
g = 39292
#coal
c = 43849
#oil
o = 53620

# %% [markdown]
# 2. Create a variable for the total consumption

# %%
tot_cons = 158839

# %% [markdown]
# 3. Create a variable for the total amount that comes from gas, coal and oil

# %%
tot_gco = g+c+o

# %% [markdown]
# 4. Print the division of the last two variables multiplied by 100 (to get the percentage)

# %%
perc_gco = (tot_gco/tot_cons)*100
print ("The global consumption of gas, coal and oil is " + str(perc_gco) + "%.")
# Out:
# The global consumption of gas, coal and oil is 86.10039096191741%.

# %% [markdown]
# **2. How many people in the world have some access to electricity?**

# %% [markdown]
# 1. Create three variables, where each variable represents the population with some access to electricity in each income cluster (resulting from the multiplication of total population by the percentage of population with access to electricity)

# %%
#I created three additional variables

#population in low income countries
pop_l = 647870823
#population in middle income countries
pop_m = 5786162963
#population in high income countries
pop_h = 1210795776

#% of population in low income countries with acess to electricity
perc_l = 40.92
#% of population in middle income countries with acess to electricity
perc_m = 93.51
#% of population in high income countries with acess to electricity
perc_h = 99.99

#population in low income countries with acess to electricity
low_i = pop_l*(perc_l/100)
#population in middle income countries with acess to electricity
middle_i = pop_m*(perc_m/100)
#population in high income countries with acess to electricity
high_i = pop_h*(perc_h/100)

#print(low_i,middle_i,high_i)

# %% [markdown]
# 2. Create a variable for the world population

# %%
pop_w = pop_l + pop_m + pop_h
#print(pop_w)

# %% [markdown]
# 3. Print the result from the division of the sum of the first three variables and the world population

# %%
#worldwide population with access to electricity
wpop_elec = low_i + middle_i + high_i
perc_w = (wpop_elec/pop_w)*100
print("The world population with access to electricity is " + str(perc_w) + "%.")
# Out:
# The world population with access to electricity is 90.07950233613462%.

# %% [markdown]
# **3. How many people in the world have access to safe drinking water in their home or close by?**

# %% [markdown]
# 1. Create a variable for the world population and a variable with water safely managed services population

# %%
#I created an additional variable

#world population with water safely managed services
pop_with = 5.4*(10**9)
pop_without = 2.25*(10**9)
#print(pop_with,pop_without)

#world population
pop_total = pop_with + pop_without
#print(pop_total)

# %% [markdown]
# 2. Create a variable for the share of population with water safely managed services that results from the division of the previous variables

# %%
perc_with = (pop_with/pop_total)*100

# %% [markdown]
# 3. Print the last variable

# %%
print("The world population with water safely managed services is " + str(perc_with) + "%." )
# Out:
# The world population with water safely managed services is 70.58823529411765%.

# %% [markdown]
# **4. Of all the freshwater used in the world, how much goes to agriculture?**

# %%
#freshwater consumed by each group of countries
brics = 1.73*(10**12)
oced = 0.93*(10**12)
row = 1.33*(10**12)
#available freshwater
ava_water = brics + oced + row
#quantity of water consumed by each industry
house = 0.11*ava_water
indu = 0.76*(10**12)

# %%
agro = ava_water-house-indu
agro_tri = agro*(10**(-9))
perc_agro = (agro/ava_water)*100
print("Of all the available freshwater agriculture uses " + str(agro_tri) + " trillion m3 of it per year.")
print("Of all the available freshwater agriculture uses " + str(perc_agro) + "% of it per year.")
# Out:
# Of all the available freshwater agriculture uses 2791.1000000000004 trillion m3 of it per year.
# Of all the available freshwater agriculture uses 69.95238095238095% of it per year.
